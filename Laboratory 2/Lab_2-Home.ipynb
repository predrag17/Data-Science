# %% [markdown]
# <a href="https://colab.research.google.com/github/jovanadobreva/Labs-I2DS/blob/main/Lab_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #<font  color='Orange'>Data Preparation & KNN Classification</font>

# %% [markdown]
# # <font color = 'Orange'> Read your Dataset (.csv)</font>
# run the code below for downloading the dataset

# %%
# !gdown 1CkUp_wtuauTNL9aOW-K52jDlTXqD4KWS
# Out:
# 'gdown' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('diabetes.csv')

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6.0      148             72           35.0        0  33.6
# 1            1.0       85             66           29.0        0  26.6
# 2            8.0      183             64            0.0        0  23.3
# 3            1.0       89             66           23.0       94  28.1
# 4            0.0      137             40           35.0      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763         10.0      101             76           48.0      180  32.9
# 764          2.0      122             70           27.0        0  36.8
# 765          5.0      121             72           23.0      112  26.2
# 766          1.0      126             60            0.0        0  30.1
# 767          1.0       93             70           31.0        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df.sample(15)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 388          5.0      144             82           26.0      285  32.0
# 289          5.0      108             72           43.0       75  36.1
# 352          3.0       61             82           28.0        0  34.4
# 470          1.0      144             82           40.0        0  41.3
# 652          5.0      123             74           40.0       77  34.1
# 119          4.0       99             76           15.0       51  23.2
# 133          8.0       84             74           31.0        0  38.3
# 2            8.0      183             64            0.0        0  23.3
# 148          5.0      147             78            0.0        0  33.7
# 399          3.0      193             70           31.0        0  34.9
# 55           1.0       73             50           10.0        0  23.0
# 628          5.0      128             80            0.0        0  34.6
# 758          1.0      106             76            0.0        0  37.5
# 206          8.0      196             76           29.0      280  37.5
# 703          2.0      129              0            0.0        0  38.5
#
#      DiabetesPedigreeFunction  Age  Outcome
# 388                     0.452   58        1
# 289                     0.263   33        0
# 352                     0.243   46        0
# 470                     0.607   28        0
# 652                     0.269   28        0
# 119                     0.223   21        0
# 133                     0.457   39        0
# 2                       0.672   32        1
# 148                     0.218   65        0
# 399                     0.241   25        1
# 55                      0.248   21        0
# 628                     0.144   45        0
# 758                     0.197   26        0
# 206                     0.605   57        1
# 703                     0.304   41        0

# %%
grouped = df.groupby('Age')['BMI'].mean()

# %%
plt.plot(grouped)
plt.show()

# %% [markdown]
# # <font color = 'Orange'> Data preprocessing </font>
#
# Context
# This dataset is originally from the National Institute of Diabetes and Digestive and Kidney Diseases. The objective of the dataset is to diagnostically predict whether or not a patient has diabetes, based on certain diagnostic measurements included in the dataset. Several constraints were placed on the selection of these instances from a larger database. In particular, all patients here are females at least 21 years old of Pima Indian heritage.
#
# Content
# The datasets consists of several medical predictor variables and one target variable, Outcome. Predictor variables includes the number of pregnancies the patient has had, their BMI, insulin level, age, and so on.

# %% [markdown]
# Input columns: Pregnancies, Glucose, BloodPressure,SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age
#
# Output columns: Outcome 0-->doesn't have diabetes / 1--> has diabetes

# %% [markdown]
# ## <font color = 'Orange'>Detect the Missing values</font>

# %% [markdown]
# Count the percentage of missing values in every column of the Dataset.

# %%
df.isnull().sum()
# Out:
# Pregnancies                 14
# Glucose                      0
# BloodPressure                0
# SkinThickness                8
# Insulin                      0
# BMI                         10
# DiabetesPedigreeFunction     0
# Age                          0
# Outcome                      0
# dtype: int64

# %%
missing_percent = df.isnull().sum() / len(df) * 100

# %%
missing_percent
# Out:
# Pregnancies                 1.822917
# Glucose                     0.000000
# BloodPressure               0.000000
# SkinThickness               1.041667
# Insulin                     0.000000
# BMI                         1.302083
# DiabetesPedigreeFunction    0.000000
# Age                         0.000000
# Outcome                     0.000000
# dtype: float64

# %%
missing_percent = missing_percent.reset_index().rename(columns={"index": "column", 0: "percent missing"})

# %%
missing_percent
# Out:
#                      column  percent missing
# 0               Pregnancies         1.822917
# 1                   Glucose         0.000000
# 2             BloodPressure         0.000000
# 3             SkinThickness         1.041667
# 4                   Insulin         0.000000
# 5                       BMI         1.302083
# 6  DiabetesPedigreeFunction         0.000000
# 7                       Age         0.000000
# 8                   Outcome         0.000000

# %% [markdown]
# ## <font color = 'Orange'> Find reasons for the missing values</font>
#
#
# With the help of visualization matrix, heatmap, dendrogram, show the dependence between the columns with missing values

# %% [markdown]
# Visualize the missing values using Missingno library

# %%
import missingno as msno

# %%
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
msno.bar(df)
plt.show()

# %%
msno.matrix(df)
plt.show()

# %%
msno.heatmap(df)
plt.show()

# %%
msno.dendrogram(df)
plt.show()

# %% [markdown]
# ## <font color = 'Orange'>Handle the missing values</font>

# %%
df.isnull().sum()
# Out:
# Pregnancies                 14
# Glucose                      0
# BloodPressure                0
# SkinThickness                8
# Insulin                      0
# BMI                         10
# DiabetesPedigreeFunction     0
# Age                          0
# Outcome                      0
# dtype: int64

# %%
from sklearn.impute import KNNImputer

# %%
imputer = KNNImputer(n_neighbors=3)

# %%
df['Pregnancies'] = imputer.fit_transform(df[['Pregnancies']])

# %%
df['BMI'] = imputer.fit_transform(df[['BMI']])

# %%
df['SkinThickness'] = imputer.fit_transform(df[['SkinThickness']])

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6.0      148             72           35.0        0  33.6
# 1            1.0       85             66           29.0        0  26.6
# 2            8.0      183             64            0.0        0  23.3
# 3            1.0       89             66           23.0       94  28.1
# 4            0.0      137             40           35.0      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763         10.0      101             76           48.0      180  32.9
# 764          2.0      122             70           27.0        0  36.8
# 765          5.0      121             72           23.0      112  26.2
# 766          1.0      126             60            0.0        0  30.1
# 767          1.0       93             70           31.0        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %% [markdown]
# ## <font color = 'Orange'>Save the new Dataset(.csv) without the missing values</font>

# %%
df.sample(100)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 183          5.0       73             60            0.0        0  26.800000
# 242          3.0      139             54            0.0        0  25.600000
# 383          1.0       90             62           18.0       59  25.100000
# 367          0.0      101             64           17.0        0  21.000000
# 464         10.0      115             98            0.0        0  24.000000
# ..           ...      ...            ...            ...      ...        ...
# 599          1.0      109             38           18.0      120  23.100000
# 313          3.0      113             50           10.0       85  29.500000
# 251          2.0      129             84            0.0        0  31.962533
# 717         10.0       94             72           18.0        0  23.100000
# 218          5.0       85             74           22.0        0  29.000000
#
#      DiabetesPedigreeFunction  Age  Outcome
# 183                     0.268   27        0
# 242                     0.402   22        1
# 383                     1.268   25        0
# 367                     0.252   21        0
# 464                     1.022   34        0
# ..                        ...  ...      ...
# 599                     0.407   26        0
# 313                     0.626   25        0
# 251                     0.284   27        0
# 717                     0.595   56        0
# 218                     1.224   32        1
#
# [100 rows x 9 columns]

# %%
df = pd.DataFrame(df)
df.to_csv('data.csv', index=False)

# %% [markdown]
# Print the first rows of your final Dataset

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0      148             72           35.0        0  33.6
# 1          1.0       85             66           29.0        0  26.6
# 2          8.0      183             64            0.0        0  23.3
# 3          1.0       89             66           23.0       94  28.1
# 4          0.0      137             40           35.0      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# # <font color='orange'>KNN Classification</font>

# %% [markdown]
# ##<font color = 'Orange'>Split the dataset for training and testing in ratio 80:20 </font>

# %%
target = 'Outcome'
X = df.drop([target], axis = 1)
Y = df[target]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

# %% [markdown]
# ## <font color = 'Orange'>Initialize the KNN Classification model, and use the fit function for training the model</font>

# %%
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier(3)
model.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# ## <font color = 'Orange'>Predict the outcomes for X test</font>

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# ## <font color = 'Orange'>See the model performance, by using sklearn metrics for classification</font>

# %%
from sklearn.metrics import classification_report, f1_score

print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.81      0.78       102
#            1       0.55      0.44      0.49        52
#
#     accuracy                           0.69       154
#    macro avg       0.64      0.63      0.63       154
# weighted avg       0.68      0.69      0.68       154

# %%
f1_scores = []
for i in range(3, 11):
    model = KNeighborsClassifier(n_neighbors=i)
    model.fit(X_train, Y_train)
    y_pred = model.predict(X_test)
    f1_scores.append(f1_score(Y_test, y_pred, average='macro'))

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([i for i in range(3, 11)], f1_scores)
